# %%
print("Hello world")
# Out:
# Hello world

# %%
import math
print (math.sqrt(100))
# Out:
# 10.0

# %%
L=[10,20,"Rahatul",40]
print(L)
L.append(100)
print(L)
print(type(L))
# Out:
# [10, 20, 'Rahatul', 40]
# [10, 20, 'Rahatul', 40, 100]
# <class 'list'>

# %%
print(type(L))
# Out:
# <class 'list'>

# %%
s={10,20,20}
print(s)
# Out:
# {10, 20}

# %%
print(s)
# Out:
# {10, 20}

# %%
print(len(s))
# Out:
# 2
